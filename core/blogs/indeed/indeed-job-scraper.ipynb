# %% [markdown]
# ---
# title: "Webscraping Indeed Job Portal"
# description: "webscraping with python "
# author: "Aakash Basnet"
# date: "2024/02/03"
# categories:
#   - webscraping
#   - code
#   - ETL
#   - python
# format:
#   html:
#     code-fold: true
# jupyter: python3
# ---

# %% [markdown]
# ##  Building URL
# After navigating the developer toolbar for Indeed job listing, I found the pattern in the url query for each job title search and location. We can use this info to build the url. The link printed from the code below will take you to the Indeed page having listing for python developer in Dalla, TX

# %%
import pandas as pd
import requests
import time

from selenium import webdriver
from selenium.webdriver.common.by import By



def url_builder(job_title, location, page_number=10 ):
    job_title = "+".join(job_title.split(" "))
    location = "+".join(location.split(" "))
    base_url = "https://www.indeed.com/jobs"
    query_str = f"?q={job_title}&l={location}"
    url = f"{base_url}{query_str}"
     
    return url

print(url_builder(job_title="python developer", location="Dallas, TX"))
# Out:
# https://www.indeed.com/jobs?q=python+developer&l=Dallas,+TX

# %% [markdown]
# ## Scraping the indeep page with selenium
# The script below scrapes the data for the given job title and location. It uses selenium web driver to automate the data scraping. The web driver clicks 'next' button on pagination until the end of the page.

# %%
def get_data(job_title, location):
    

    url = url_builder(job_title=job_title, location=location)
    driver = webdriver.Chrome()
    driver.get(url)
    time.sleep(5)

    jobs = []
    has_next = True
    count = 1
    while has_next:
        
        time.sleep(10)
        cards = driver.find_elements(By.CLASS_NAME,'cardOutline')
        for card in cards:
            job_title = card.find_element(By.CLASS_NAME,'jobTitle')
            job_title_text = job_title.text
            job_id = job_title.find_element(By.TAG_NAME, 'a').get_attribute('data-jk')
            location = card.find_element(By.CLASS_NAME,'company_location').text
            job_description = card.find_element(By.CLASS_NAME,'underShelfFooter').text
            
            try:
                pay,*_metadata = card.find_element(By.CLASS_NAME,'heading6').text.split('\n')
            except Exception as e:
                pay = 'NA'
                _metadata = []
        
            
            jobs.append({
                'job_title':job_title_text,
                'location': location,
                'description': job_description,
                'pay rate': pay,
                'metadata': _metadata,
                'job_id':job_id,
                'job_url': f"https://www.indeed.com/viewjob?jk={job_id}",
                
            })

        try:
            driver.find_element(By.CSS_SELECTOR,"[data-testid='pagination-page-next']").click()
            count += 1
        except Exception as e:
            print(f"Ending at page {count}")
            has_next = False

    driver.close()
    return jobs

# %%
job_data = get_data(job_title='python developer', location='Fort Worth,TX')
# Out:
# Ending at page 2

# %%
df = pd.DataFrame(job_data)
df.head(40)
# Out:
#                                             job_title  \
# 0   Python Programmer who enjoys helping people sm...
# 1                                  Software Developer
# 2                                  Software Developer
# 3   Python Developer || Dallas, TX (Local only) ||...
# 4                                    Python Developer
# 5                Python FullStack Developer with Node
# 6   Python Developer _ (Local to Dallas, TX)- Onsi...
# 7                                    Python Developer
# 8                                    Python Developer
# 9                                    Python Developer
# 10                             Lead Software Engineer
# 11                        Python Developer- $100-110K
# 12                               Sr. Python Developer
# 13                              Java Python Developer
# 14                                Python Sr Developer
#
#                                            location  \
# 0                           Lifecorp\nArlington, TX
# 1                                  lead4ward\nTexas
# 2        Dream Entertainment Labs\nDallas, TX 75252
# 3                ANB Sourcing LLC\nDallas, TX 75201
# 4     E-Business International Inc\nPlano, TX 75024
# 5                       Inclusion Cloud\nDallas, TX
# 6                ANB Sourcing LLC\nDallas, TX 75201
# 7   InfoQuest Consulting Group Inc.\nFort Worth, TX
# 8                  Tek Ninjas\nFort Worth, TX 76120
# 9         Qatalys Software Technologies\nIrving, TX
# 10                Capital One\n3.9\nPlano, TX 75023
# 11          Fults & Associates\nGrapevine, TX 76051
# 12            Amazee Global Ventures Inc\nPlano, TX
# 13                          Infosys\nRichardson, TX
# 14                      Inclusion Cloud\nDallas, TX
#
#                                           description  \
# 0   Python Programmer who enjoys helping people sm...
# 1   As part of a small, focused team, you’ll provi...
# 2   Projects will center around family entertainme...
# 3   Mid-level (5 or more years) in Python Developm...
# 4   Create Golang based microservices and librarie...
# 5   Provide technical guidance and support to juni...
# 6   Dallas, TX (Onsite job)-- Local only.\nEmploye...
# 7   Duration & Type: 6 months Contract with a majo...
# 8   Position: Python Developer Location: Fort Wort...
# 9   Analyzes business and technical requirements t...
# 10  These advancements will then allow high-qualit...
# 11  Need someone who works a lot with Software.\nM...
# 12  Experience in leading development teams and me...
# 13  Experience in python development and libraries...
# 14  Active participation in agile (scrum) developm...
#
#                         pay rate                            metadata  \
# 0      $70,000 - $100,000 a year  [Full-time, Choose your own hours]
# 1     $100,000 - $120,000 a year   [Full-time, Monday to Friday, +1]
# 2       $60,000 - $75,000 a year                         [Full-time]
# 3                                                                 []
# 4                                                                 []
# 5                                                                 []
# 6                                                                 []
# 7                                                                 []
# 8                                                                 []
# 9                                                                 []
# 10  Pay information not provided                         [Full-time]
# 11                                                                []
# 12             $55 - $60 an hour   [Full-time, +1, Monday to Friday]
# 13  Pay information not provided                                  []
# 14  Pay information not provided                                  []
#
#               job_id                                            job_url
# 0   ff1fe7ff0d3d04ad  https://www.indeed.com/viewjob?jk=ff1fe7ff0d3d...
# 1   6c7f467bada6cc22  https://www.indeed.com/viewjob?jk=6c7f467bada6...
# 2   c32a429e080a48f0  https://www.indeed.com/viewjob?jk=c32a429e080a...
# 3   d5dfbda8e8a781b1  https://www.indeed.com/viewjob?jk=d5dfbda8e8a7...
# 4   a0caa2b4d714913d  https://www.indeed.com/viewjob?jk=a0caa2b4d714...
# 5   ec46c96556d4c31d  https://www.indeed.com/viewjob?jk=ec46c96556d4...
# 6   fbe285b925e08a10  https://www.indeed.com/viewjob?jk=fbe285b925e0...
# 7   e3232c051e279108  https://www.indeed.com/viewjob?jk=e3232c051e27...
# 8   a002a17ed558d9a8  https://www.indeed.com/viewjob?jk=a002a17ed558...
# 9   a2a8cbd917cbf446  https://www.indeed.com/viewjob?jk=a2a8cbd917cb...
# 10  92491b6cd1e2158f  https://www.indeed.com/viewjob?jk=92491b6cd1e2...
# 11  b308d7d83046bef9  https://www.indeed.com/viewjob?jk=b308d7d83046...
# 12  85e34afe849476f4  https://www.indeed.com/viewjob?jk=85e34afe8494...
# 13  fbf2ba53d3fc0f3e  https://www.indeed.com/viewjob?jk=fbf2ba53d3fc...
# 14  b4fe0b9fcc1b77d5  https://www.indeed.com/viewjob?jk=b4fe0b9fcc1b...

# %%
df.shape
# Out:
# (15, 7)

# %% [markdown]
# ## Rotating Proxies
# The proxies needs to be rotated to not be detected by anti scrapping tools used by the servers. For this we will scrape the list of free available ip address and test them using multithreading. This will filter the working proxies. Later on, we will use working proxies to make the request

# %%
def extract_proxies():
    print("Extracting proxies...")
    proxy_url  = "https://www.us-proxy.org/"
    r = requests.get(proxy_url)
    dfs  = pd.read_html(r.text)
    df = dfs[0]
    print(df.shape)
    return df
proxies_df = extract_proxies()
proxies_df.head(20)
# Out:
# /var/folders/22/2rvpv_m90c30mhtk77k1jd440000gn/T/ipykernel_39218/3797928275.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# Extracting proxies...
# (200, 8)
# /var/folders/22/2rvpv_m90c30mhtk77k1jd440000gn/T/ipykernel_39218/3797928275.py:9: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs  = pd.read_html(r.text)
#          IP Address  Port Code        Country    Anonymity Google Https  \
# 0   104.225.220.233    80   US  United States  elite proxy    yes    no
# 1     23.254.231.55    80   US  United States  elite proxy    yes    no
# 2     50.217.226.42    80   US  United States    anonymous     no    no
# 3    50.223.239.185    80   US  United States    anonymous     no    no
# 4     50.174.145.15    80   US  United States    anonymous     no    no
# 5    50.174.214.220    80   US  United States    anonymous     no    no
# 6     50.217.226.46    80   US  United States    anonymous     no    no
# 7      50.200.12.83    80   US  United States    anonymous     no    no
# 8     50.168.72.118    80   US  United States    anonymous     no    no
# 9     50.207.199.85    80   US  United States    anonymous     no    no
# 10   50.174.214.219    80   US  United States    anonymous     no    no
# 11     68.185.57.66    80   US  United States    anonymous     no    no
# 12    50.221.74.130    80   US  United States    anonymous     no    no
# 13     50.174.145.8    80   US  United States    anonymous     no    no
# 14   50.173.140.151    80   US  United States    anonymous     no    no
# 15    50.168.72.115    80   US  United States    anonymous     no    no
# 16     50.170.90.27    80   US  United States    anonymous     no    no
# 17   50.168.163.176    80   US  United States    anonymous     no    no
# 18   50.223.246.226    80   US  United States    anonymous     no    no
# 19    50.207.199.84    80   US  United States    anonymous     no    no
#
#    Last Checked
# 0    3 secs ago
# 1    3 secs ago
# 2    4 secs ago
# 3    4 secs ago
# 4    4 secs ago
# 5    4 secs ago
# 6    4 secs ago
# 7    4 secs ago
# 8    4 secs ago
# 9    4 secs ago
# 10   4 secs ago
# 11   4 secs ago
# 12   4 secs ago
# 13   4 secs ago
# 14   4 secs ago
# 15   4 secs ago
# 16   4 secs ago
# 17   4 secs ago
# 18   4 secs ago
# 19   4 secs ago
